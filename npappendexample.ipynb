# %%
import numpy as np
from random import randint
from matplotlib import pyplot as plt
x=list()
y=list()

for i in range(1000):
    a=randint(1,100000)
    b=i
    x.append(a)
    y.append(b)
plt.plot(y,x)
